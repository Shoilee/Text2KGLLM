# %%
text = \
"""id: https://w3id.org/linkml/examples/person
name: personinfo
prefixes:
  linkml: https://w3id.org/linkml/
  person: https://w3id.org/linkml/examples/person/
imports:
  - linkml:types
  - core
default_range: string
default_prefix: person

classes:

  Person:
    is_a: NamedEntity
    tree_root: true

    description: >-
      Represents a person with various personal and familial attributes.
    attributes:
      id:
        description: >-
          A unique identifier for the person, typically derived from the full name.
          For example, use lowercase letters with underscores or hyphens.
        identifier: true
        range: string

      full_name:
        description: >-
          The complete name of the person as known in historical or biographical records.
        range: string
        required: true
        

      givenName:
        description: >-
          The given (first) name of the person.
        range: string

      familyName:
        description: >-
          The family or last name of the person.
        range: string

      fatherName:
        description: >-
          The father's name associated with this person.
        range: string

      motherName:
        description: >-
          The mother's name associated with this person.
        range: string

      lastResidence:
        description: >-
          The last known residence or location where the person lived.
        range: string

      dateOfBirth:
        description: >-
          The date of birth of the person, formatted as a string (e.g., YYYY-MM-DD).
        range: string

      placeOfBirth:
        description: >-
          The location or place where the person was born.
        range: string

"""
with open('person.yaml', 'w') as outfile:
    outfile.write(text)

# %%
# %%bash
# echo "Rochell Josephus Hendrik was born on March 11, 1789, in Wageningen. He was the son of Samuel and Getruida Merkes, and his last known place of residence was Rotterdam." > example.txt

# %%
# %%bash
# ontogpt extract -i example.txt -t person.yaml -m ollama/llama3
# Out:
# ERROR:root:Cannot find slot for here_are_the_extracted_entities_in_the_requested_format in Here are the extracted entities in the requested format:
# ERROR:root:Cannot find slot for ; in ;
# ERROR:root:Cannot find slot for givenname in givenName: Rochell
# ERROR:root:Cannot find slot for familyname in familyName: Hendrik
# ERROR:root:Cannot find slot for fathername in fatherName: Samuel
# ERROR:root:Cannot find slot for mothername in motherName: Getruida Merkes
# ERROR:root:Cannot find slot for lastresidence in lastResidence: Rotterdam
# ERROR:root:Cannot find slot for dateofbirth in dateOfBirth: 1789-03-11
# ERROR:root:Cannot find slot for placeofbirth in placeOfBirth: Wageningen
# ---
# input_text: |
#   Rochell Josephus Hendrik was born on March 11, 1789, in Wageningen. He was the son of Samuel and Getruida Merkes, and his last known place of residence was Rotterdam.
# raw_completion_output: |-
#   Here are the extracted entities in the requested format:
#
#   1.
#   id: rochell_josephus_hendrik
#   full_name: Rochell Josephus Hendrik
#   givenName: Rochell
#   familyName: Hendrik
#   fatherName: Samuel
#   motherName: Getruida Merkes
#   lastResidence: Rotterdam
#   dateOfBirth: 1789-03-11
#   placeOfBirth: Wageningen
#   label: Rochell Josephus Hendrik
# prompt: |+
#   From the text below, extract the following entities in the following format:
#
#   id: <A unique identifier for the person, typically derived from the full name. For example, use lowercase letters with underscores or hyphens.>
#   full_name: <The complete name of the person as known in historical or biographical records.>
#   givenName: <The given (first) name of the person.>
#   familyName: <The family or last name of the person.>
#   fatherName: <The father's name associated with this person.>
#   motherName: <The mother's name associated with this person.>
#   lastResidence: <The last known residence or location where the person lived.>
#   dateOfBirth: <The date of birth of the person, formatted as a string (e.g., YYYY-MM-DD).>
#   placeOfBirth: <The location or place where the person was born.>
#   label: <The label (name) of the named thing>
#
#
#   Text:
#   Rochell Josephus Hendrik was born on March 11, 1789, in Wageningen. He was the son of Samuel and Getruida Merkes, and his last known place of residence was Rotterdam.
#
#
#   ===
#
# extracted_object:
#   id: 719ab94c-e962-420f-8dd6-3b12086361d3
#   label: Rochell Josephus Hendrik
#   full_name: Rochell Josephus Hendrik
